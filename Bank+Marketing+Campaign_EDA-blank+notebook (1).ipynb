# %% [markdown]
# ## Bank Telemarketing Campaign Case Study.

# %% [markdown]
# In this case study you’ll be learning Exploratory Data Analytics with the help of a case study on "Bank marketing campaign". This will enable you to understand why EDA is a most important step in the process of Machine Learning.

# %% [markdown]
# #### Problem Statement:

# %% [markdown]
#
#
# The bank provides financial services/products such as savings accounts, current accounts, debit cards, etc. to its customers. In order to increase its overall revenue, the bank conducts various marketing campaigns for its financial products such as credit cards, term deposits, loans, etc. These campaigns are intended for the bank’s existing customers. However, the marketing campaigns need to be cost-efficient so that the bank not only increases their overall revenues but also the total profit. You need to apply your knowledge of EDA on the given dataset to analyse the patterns and provide inferences/solutions for the future marketing campaign.
#
# The bank conducted a telemarketing campaign for one of its financial products ‘Term Deposits’ to help foster long-term relationships with existing customers. The dataset contains information about all the customers who were contacted during a particular year to open term deposit accounts.
#
#
# **What is the term Deposit?**
#
# Term deposits also called fixed deposits, are the cash investments made for a specific time period ranging from 1 month to 5 years for predetermined fixed interest rates. The fixed interest rates offered for term deposits are higher than the regular interest rates for savings accounts. The customers receive the total amount (investment plus the interest) at the end of the maturity period. Also, the money can only be withdrawn at the end of the maturity period. Withdrawing money before that will result in an added penalty associated, and the customer will not receive any interest returns.
#
# Your target is to do end to end EDA on this bank telemarketing campaign data set to infer knowledge that where bank has to put more effort to improve it's positive response rate.

# %% [markdown]
# #### Importing the libraries.

# %%
#import the warnings.

# %%
#import the useful libraries.
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Session- 2, Data Cleaning

# %% [markdown]
# ### Segment- 2, Data Types

# %% [markdown]
# There are multiple types of data types available in the data set. some of them are numerical type and some of categorical type. You are required to get the idea about the data types after reading the data frame.
#
# Following are the some of the types of variables:
# - **Numeric data type**: banking dataset: salary, balance, duration and age.
# - **Categorical data type**: banking dataset: education, job, marital, poutcome and month etc.
# - **Ordinal data type**: banking dataset: Age group.
# - **Time and date type**
# - **Coordinates type of data**: latitude and longitude type.

# %% [markdown]
# #### Read in the Data set.

# %%
#read the data set of "bank telemarketing campaign" in inp0.

inp0= pd.read_csv('/mnt/d/Bank Dataset/bank_marketing_updated_v1.csv')

# %%
#Print the head of the data frame.
inp0.head()
# Out:
#       banking marketing Unnamed: 1                    Unnamed: 2 Unnamed: 3  \
# 0  customer id and age.        NaN  Customer salary and balance.        NaN
# 1            customerid        age                        salary    balance
# 2                     1         58                        100000       2143
# 3                     2         44                         60000         29
# 4                     3         33                        120000          2
#
#                                           Unnamed: 4              Unnamed: 5  \
# 0  Customer marital status and job with education...                     NaN
# 1                                            marital                  jobedu
# 2                                            married     management,tertiary
# 3                                             single    technician,secondary
# 4                                            married  entrepreneur,secondary
#
#                                    Unnamed: 6 Unnamed: 7  \
# 0  particular customer before targeted or not        NaN
# 1                                    targeted    default
# 2                                         yes         no
# 3                                         yes         no
# 4                                         yes         no
#
#                            Unnamed: 8 Unnamed: 9   Unnamed: 10 Unnamed: 11  \
# 0  Loan types: loans or housing loans        NaN  Contact type         NaN
# 1                             housing       loan       contact         day
# 2                                 yes         no       unknown           5
# 3                                 yes         no       unknown           5
# 4                                 yes        yes       unknown           5
#
#         Unnamed: 12       Unnamed: 13 Unnamed: 14 Unnamed: 15 Unnamed: 16  \
# 0  month of contact  duration of call         NaN         NaN         NaN
# 1             month          duration    campaign       pdays    previous
# 2         may, 2017           261 sec           1          -1           0
# 3         may, 2017           151 sec           1          -1           0
# 4         may, 2017            76 sec           1          -1           0
#
#                    Unnamed: 17                              Unnamed: 18
# 0  outcome of previous contact  response of customer after call happned
# 1                     poutcome                                 response
# 2                      unknown                                       no
# 3                      unknown                                       no
# 4                      unknown                                       no

# %% [markdown]
# ### Segment- 3, Fixing the Rows and Columns

# %% [markdown]
# Checklist for fixing rows:
# - **Delete summary rows**: Total and Subtotal rows
# - **Delete incorrect rows**: Header row and footer row
# - **Delete extra rows**: Column number, indicators, Blank rows, Page No.
#
# Checklist for fixing columns:
# - **Merge columns for creating unique identifiers**, if needed, for example, merge the columns State and City into the column Full address.
# - **Split columns to get more data**: Split the Address column to get State and City columns to analyse each separately.
# - **Add column names**: Add column names if missing.
# - **Rename columns consistently**: Abbreviations, encoded columns.
# - **Delete columns**: Delete unnecessary columns.
# - **Align misaligned columns**: The data set may have shifted columns, which you need to align correctly.

# %% [markdown]
# #### Read the file without unnecessary headers.

# %%
#read the file in inp0 without first two rows as it is of no use.
inp0.columns=inp0.iloc[1]
inp0= inp0[2:]
inp0
# Out:
# 1     customerid age  salary balance   marital                  jobedu  \
# 2              1  58  100000    2143   married     management,tertiary
# 3              2  44   60000      29    single    technician,secondary
# 4              3  33  120000       2   married  entrepreneur,secondary
# 5              4  47   20000    1506   married     blue-collar,unknown
# 6              5  33       0       1    single         unknown,unknown
# 7              6  35  100000     231   married     management,tertiary
# 8              7  28  100000     447    single     management,tertiary
# 9              8  42  120000       2  divorced   entrepreneur,tertiary
# 10             9  58   55000     121   married         retired,primary
# 11            10  43   60000     593    single    technician,secondary
# 12            11  41   50000     270  divorced        admin.,secondary
# 13            12  29   50000     390    single        admin.,secondary
# 14            13  53   60000       6   married    technician,secondary
# 15            14  58   60000      71   married      technician,unknown
# 16            15  57   70000     162   married      services,secondary
# 17            16  51   55000     229   married         retired,primary
# 18            17  45   50000      13    single          admin.,unknown
# 19            18  57   20000      52   married     blue-collar,primary
# 20            19  60   55000      60   married         retired,primary
# 21            20  33   70000       0   married      services,secondary
# 22            21  28   20000     723   married   blue-collar,secondary
# 23            22  56  100000     779   married     management,tertiary
# 24            23  32   20000      23    single     blue-collar,primary
# 25            24  25   70000      50   married      services,secondary
# 26            25  40   55000       0   married         retired,primary
# 27            26  44   50000    -372   married        admin.,secondary
# 28            27  39  100000     255    single     management,tertiary
# 29            28  52  120000     113   married  entrepreneur,secondary
# 30            29  46  100000    -246    single    management,secondary
# 31            30  36   60000     265    single    technician,secondary
# ...          ...  ..     ...     ...       ...                     ...
# 45183      45182  46   20000    6879   married   blue-collar,secondary
# 45184      45183  34   60000     133   married    technician,secondary
# 45185      45184  70   55000     324   married         retired,primary
# 45186      45185  63   55000    1495   married       retired,secondary
# 45187      45186  60   70000    4256   married       services,tertiary
# 45188      45187  59       0    1500   married         unknown,unknown
# 45189      45188  32   70000    1168    single      services,secondary
# 45190      45189  29  100000     703    single    management,secondary
# 45191      45190  25   70000     199    single      services,secondary
# 45192      45191  32   20000     136   married   blue-collar,secondary
# 45193      45192  75   55000    3810  divorced        retired,tertiary
# 45194      45193  29  100000     765    single     management,tertiary
# 45195      45194  28   60000     159    single  self-employed,tertiary
# 45196      45195  59  100000     138   married     management,tertiary
# 45197      45196  68   55000    1146   married       retired,secondary
# 45198      45197  25    4000     358    single       student,secondary
# 45199      45198  36  100000    1511    single    management,secondary
# 45200      45199  37  100000    1428   married     management,tertiary
# 45201      45200  34   20000    1475    single   blue-collar,secondary
# 45202      45201  38   60000     557   married    technician,secondary
# 45203      45202  53  100000     583   married     management,tertiary
# 45204      45203  34   50000     557    single        admin.,secondary
# 45205      45204  23    4000     113    single        student,tertiary
# 45206      45205  73   55000    2850   married       retired,secondary
# 45207      45206  25   60000     505    single    technician,secondary
# 45208      45207  51   60000     825   married     technician,tertiary
# 45209      45208  71   55000    1729  divorced         retired,primary
# 45210      45209  72   55000    5715   married       retired,secondary
# 45211      45210  57   20000     668   married   blue-collar,secondary
# 45212      45211  37  120000    2971   married  entrepreneur,secondary
#
# 1     targeted default housing loan    contact day      month  \
# 2          yes      no     yes   no    unknown   5  may, 2017
# 3          yes      no     yes   no    unknown   5  may, 2017
# 4          yes      no     yes  yes    unknown   5  may, 2017
# 5           no      no     yes   no    unknown   5  may, 2017
# 6           no      no      no   no    unknown   5  may, 2017
# 7          yes      no     yes   no    unknown   5  may, 2017
# 8           no      no     yes  yes    unknown   5  may, 2017
# 9           no     yes     yes   no    unknown   5  may, 2017
# 10         yes      no     yes   no    unknown   5  may, 2017
# 11         yes      no     yes   no    unknown   5  may, 2017
# 12         yes      no     yes   no    unknown   5  may, 2017
# 13         yes      no     yes   no    unknown   5  may, 2017
# 14         yes      no     yes   no    unknown   5  may, 2017
# 15          no      no     yes   no    unknown   5  may, 2017
# 16         yes      no     yes   no    unknown   5  may, 2017
# 17         yes      no     yes   no    unknown   5  may, 2017
# 18          no      no     yes   no    unknown   5  may, 2017
# 19         yes      no     yes   no    unknown   5  may, 2017
# 20         yes      no     yes   no    unknown   5  may, 2017
# 21         yes      no     yes   no    unknown   5  may, 2017
# 22         yes      no     yes  yes    unknown   5  may, 2017
# 23         yes      no     yes   no    unknown   5  may, 2017
# 24         yes      no     yes  yes    unknown   5  may, 2017
# 25         yes      no     yes   no    unknown   5  may, 2017
# 26         yes      no     yes  yes    unknown   5  may, 2017
# 27         yes      no     yes   no    unknown   5  may, 2017
# 28          no      no     yes   no    unknown   5  may, 2017
# 29         yes      no     yes  yes    unknown   5  may, 2017
# 30         yes      no     yes   no    unknown   5  may, 2017
# 31         yes      no     yes  yes    unknown   5  may, 2017
# ...        ...     ...     ...  ...        ...  ..        ...
# 45183      yes      no      no   no   cellular  15  nov, 2017
# 45184      yes      no      no   no   cellular  15  nov, 2017
# 45185      yes      no      no   no   cellular  15  nov, 2017
# 45186      yes      no      no   no   cellular  16  nov, 2017
# 45187      yes      no     yes   no   cellular  16  nov, 2017
# 45188       no      no      no   no   cellular  16  nov, 2017
# 45189      yes      no     yes   no   cellular  16  nov, 2017
# 45190      yes      no     yes   no   cellular  16  nov, 2017
# 45191      yes      no      no   no   cellular  16  nov, 2017
# 45192      yes      no      no   no   cellular  16  nov, 2017
# 45193       no      no     yes   no   cellular  16  nov, 2017
# 45194       no      no      no   no   cellular  16  nov, 2017
# 45195       no      no      no   no   cellular  16  nov, 2017
# 45196      yes      no     yes  yes   cellular  16  nov, 2017
# 45197      yes      no      no   no   cellular  16  nov, 2017
# 45198      yes      no      no   no   cellular  16  nov, 2017
# 45199      yes      no     yes   no   cellular  16  nov, 2017
# 45200      yes      no      no   no   cellular  16  nov, 2017
# 45201      yes      no     yes   no   cellular  16  nov, 2017
# 45202      yes      no     yes   no   cellular  16  nov, 2017
# 45203      yes      no      no   no   cellular  17  nov, 2017
# 45204      yes      no      no   no   cellular  17  nov, 2017
# 45205       no      no      no   no   cellular  17  nov, 2017
# 45206      yes      no      no   no   cellular  17  nov, 2017
# 45207      yes      no      no  yes   cellular  17  nov, 2017
# 45208      yes      no      no   no   cellular  17  nov, 2017
# 45209      yes      no      no   no   cellular  17  nov, 2017
# 45210      yes      no      no   no   cellular  17  nov, 2017
# 45211      yes      no      no   no  telephone  17  nov, 2017
# 45212      yes      no      no   no   cellular  17  nov, 2017
#
# 1                  duration campaign pdays previous poutcome response
# 2                   261 sec        1    -1        0  unknown       no
# 3                   151 sec        1    -1        0  unknown       no
# 4                    76 sec        1    -1        0  unknown       no
# 5                    92 sec        1    -1        0  unknown       no
# 6                   198 sec        1    -1        0  unknown       no
# 7                   139 sec        1    -1        0  unknown       no
# 8                   217 sec        1    -1        0  unknown       no
# 9                   380 sec        1    -1        0  unknown       no
# 10                   50 sec        1    -1        0  unknown       no
# 11                   55 sec        1    -1        0  unknown       no
# 12                  222 sec        1    -1        0  unknown       no
# 13                  137 sec        1    -1        0  unknown       no
# 14                  517 sec        1    -1        0  unknown       no
# 15                   71 sec        1    -1        0  unknown       no
# 16                  174 sec        1    -1        0  unknown       no
# 17                  353 sec        1    -1        0  unknown       no
# 18                   98 sec        1    -1        0  unknown       no
# 19                   38 sec        1    -1        0  unknown       no
# 20                  219 sec        1    -1        0  unknown       no
# 21                   54 sec        1    -1        0  unknown       no
# 22                  262 sec        1    -1        0  unknown       no
# 23                  164 sec        1    -1        0  unknown       no
# 24                  160 sec        1    -1        0  unknown       no
# 25                  342 sec        1    -1        0  unknown       no
# 26                  181 sec        1    -1        0  unknown       no
# 27                  172 sec        1    -1        0  unknown       no
# 28                  296 sec        1    -1        0  unknown       no
# 29                  127 sec        1    -1        0  unknown       no
# 30                  255 sec        2    -1        0  unknown       no
# 31                  348 sec        1    -1        0  unknown       no
# ...                     ...      ...   ...      ...      ...      ...
# 45183  1.23333333333333 min        2   118        3  failure       no
# 45184  6.68333333333333 min        2   187        5  success      yes
# 45185               1.3 min        1    96        7  success       no
# 45186               2.3 min        1    22        5  success       no
# 45187  3.33333333333333 min        1    92        4  success      yes
# 45188  4.66666666666667 min        1   104        2  failure       no
# 45189              6.85 min        1    -1        0  unknown      yes
# 45190  3.93333333333333 min        1   550        2  success      yes
# 45191  2.88333333333333 min        1    92        5  failure       no
# 45192  3.43333333333333 min        1   188        3  success      yes
# 45193  4.36666666666667 min        1   183        1  failure      yes
# 45194  3.96666666666667 min        1    -1        0  unknown      yes
# 45195  7.48333333333333 min        2    33        4  success      yes
# 45196               2.7 min        2   187        5  failure       no
# 45197  3.53333333333333 min        1   187        6  success      yes
# 45198               5.5 min        1    -1        0  unknown      yes
# 45199               4.5 min        1    -1        0  unknown      yes
# 45200              5.55 min        2    -1        0  unknown       no
# 45201  19.4333333333333 min        3   530       12    other       no
# 45202  25.9333333333333 min        4    -1        0  unknown      yes
# 45203  3.76666666666667 min        1   184        4  success      yes
# 45204  3.73333333333333 min        1    -1        0  unknown      yes
# 45205  4.43333333333333 min        1    -1        0  unknown      yes
# 45206                 5 min        1    40        8  failure      yes
# 45207  6.43333333333333 min        2    -1        0  unknown      yes
# 45208  16.2833333333333 min        3    -1        0  unknown      yes
# 45209               7.6 min        2    -1        0  unknown      yes
# 45210  18.7833333333333 min        5   184        3  success      yes
# 45211  8.46666666666667 min        4    -1        0  unknown       no
# 45212  6.01666666666667 min        2   188       11    other       no
#
# [45211 rows x 19 columns]

# %%
#print the head of the data frame.
inp0.head()
# Out:
# 1 customerid age  salary balance  marital                  jobedu targeted  \
# 2          1  58  100000    2143  married     management,tertiary      yes
# 3          2  44   60000      29   single    technician,secondary      yes
# 4          3  33  120000       2  married  entrepreneur,secondary      yes
# 5          4  47   20000    1506  married     blue-collar,unknown       no
# 6          5  33       0       1   single         unknown,unknown       no
#
# 1 default housing loan  contact day      month duration campaign pdays  \
# 2      no     yes   no  unknown   5  may, 2017  261 sec        1    -1
# 3      no     yes   no  unknown   5  may, 2017  151 sec        1    -1
# 4      no     yes  yes  unknown   5  may, 2017   76 sec        1    -1
# 5      no     yes   no  unknown   5  may, 2017   92 sec        1    -1
# 6      no      no   no  unknown   5  may, 2017  198 sec        1    -1
#
# 1 previous poutcome response
# 2        0  unknown       no
# 3        0  unknown       no
# 4        0  unknown       no
# 5        0  unknown       no
# 6        0  unknown       no

# %%
#print the information of variables to check their data types.

inp0.describe()
# Out:
# 1      customerid    age salary balance  marital               jobedu  \
# count       45211  45191  45211   45211    45211                45211
# unique      45211    144     22   10334        3                   48
# top         30217     32  20000       0  married  management,tertiary
# freq            1   1509   7290    2767    27214                 7801
#
# 1      targeted default housing   loan   contact    day      month duration  \
# count     45211   45211   45211  45211     45211  45211      45161    45211
# unique        2       2       2      2         3     62         12     2646
# top         yes      no     yes     no  cellular     20  may, 2017  1.5 min
# freq      37091   44396   25130  37967     29285   2030      13747      138
#
# 1      campaign  pdays previous poutcome response
# count     45211  45211    45211    45211    45181
# unique       66    836       71        4        2
# top           1     -1        0  unknown       no
# freq      11502  30277    30277    36959    39894

# %%
#convert the age variable data type from float to integer.
inp0['age'] =inp0['age'].astype(float)
#inp0['age'].astype(int)

inp0.age.unique()
# Out:
# array([58., 44., 33., 47., 35., 28., 42., 43., 41., 29., 53., 57., 51.,
#        45., 60., 56., 32., 25., 40., 39., 52., 46., 36., 49., 59., 37.,
#        50., 54., 55., 48., 24., 38., 31., 30., 27., 34., 23., 26., nan,
#        61., 22., 21., 20., 66., 62., 83., 75., 67., 70., 65., 68., 64.,
#        69., 72., 71., 19., 76., 85., 63., 90., 82., 73., 74., 78., 80.,
#        94., 79., 77., 86., 95., 81., 18., 89., 84., 87., 92., 93., 88.])

# %%
#print the average age of customers.
inp0['age'].mean()
# Out:
# 40.93565090394105

# %% [markdown]
# #### Dropping customer id column.

# %%
#drop the customer id as it is of no use.
inp0.drop(columns=['customerid'], inplace=True)

# %% [markdown]
# #### Dividing "jobedu" column into job and education categories.

# %%
#Extract job in newly created 'job' column from "jobedu" column.
inp0['job']=inp0['jobedu'].astype(str).str.split(',').str[0]

# %%
#Extract education in newly created 'education' column from "jobedu" column.
inp0['education']= inp0['jobedu'].astype(str).str.split(',').str[1]

# %%
#drop the "jobedu" column from the dataframe.
inp0.drop(columns=['jobedu'])
# Out:
# 1       age  salary balance   marital targeted default housing loan  \
# 2      58.0  100000    2143   married      yes      no     yes   no
# 3      44.0   60000      29    single      yes      no     yes   no
# 4      33.0  120000       2   married      yes      no     yes  yes
# 5      47.0   20000    1506   married       no      no     yes   no
# 6      33.0       0       1    single       no      no      no   no
# 7      35.0  100000     231   married      yes      no     yes   no
# 8      28.0  100000     447    single       no      no     yes  yes
# 9      42.0  120000       2  divorced       no     yes     yes   no
# 10     58.0   55000     121   married      yes      no     yes   no
# 11     43.0   60000     593    single      yes      no     yes   no
# 12     41.0   50000     270  divorced      yes      no     yes   no
# 13     29.0   50000     390    single      yes      no     yes   no
# 14     53.0   60000       6   married      yes      no     yes   no
# 15     58.0   60000      71   married       no      no     yes   no
# 16     57.0   70000     162   married      yes      no     yes   no
# 17     51.0   55000     229   married      yes      no     yes   no
# 18     45.0   50000      13    single       no      no     yes   no
# 19     57.0   20000      52   married      yes      no     yes   no
# 20     60.0   55000      60   married      yes      no     yes   no
# 21     33.0   70000       0   married      yes      no     yes   no
# 22     28.0   20000     723   married      yes      no     yes  yes
# 23     56.0  100000     779   married      yes      no     yes   no
# 24     32.0   20000      23    single      yes      no     yes  yes
# 25     25.0   70000      50   married      yes      no     yes   no
# 26     40.0   55000       0   married      yes      no     yes  yes
# 27     44.0   50000    -372   married      yes      no     yes   no
# 28     39.0  100000     255    single       no      no     yes   no
# 29     52.0  120000     113   married      yes      no     yes  yes
# 30     46.0  100000    -246    single      yes      no     yes   no
# 31     36.0   60000     265    single      yes      no     yes  yes
# ...     ...     ...     ...       ...      ...     ...     ...  ...
# 45183  46.0   20000    6879   married      yes      no      no   no
# 45184  34.0   60000     133   married      yes      no      no   no
# 45185  70.0   55000     324   married      yes      no      no   no
# 45186  63.0   55000    1495   married      yes      no      no   no
# 45187  60.0   70000    4256   married      yes      no     yes   no
# 45188  59.0       0    1500   married       no      no      no   no
# 45189  32.0   70000    1168    single      yes      no     yes   no
# 45190  29.0  100000     703    single      yes      no     yes   no
# 45191  25.0   70000     199    single      yes      no      no   no
# 45192  32.0   20000     136   married      yes      no      no   no
# 45193  75.0   55000    3810  divorced       no      no     yes   no
# 45194  29.0  100000     765    single       no      no      no   no
# 45195  28.0   60000     159    single       no      no      no   no
# 45196  59.0  100000     138   married      yes      no     yes  yes
# 45197  68.0   55000    1146   married      yes      no      no   no
# 45198  25.0    4000     358    single      yes      no      no   no
# 45199  36.0  100000    1511    single      yes      no     yes   no
# 45200  37.0  100000    1428   married      yes      no      no   no
# 45201  34.0   20000    1475    single      yes      no     yes   no
# 45202  38.0   60000     557   married      yes      no     yes   no
# 45203  53.0  100000     583   married      yes      no      no   no
# 45204  34.0   50000     557    single      yes      no      no   no
# 45205  23.0    4000     113    single       no      no      no   no
# 45206  73.0   55000    2850   married      yes      no      no   no
# 45207  25.0   60000     505    single      yes      no      no  yes
# 45208  51.0   60000     825   married      yes      no      no   no
# 45209  71.0   55000    1729  divorced      yes      no      no   no
# 45210  72.0   55000    5715   married      yes      no      no   no
# 45211  57.0   20000     668   married      yes      no      no   no
# 45212  37.0  120000    2971   married      yes      no      no   no
#
# 1        contact day      month              duration campaign pdays previous  \
# 2        unknown   5  may, 2017               261 sec        1    -1        0
# 3        unknown   5  may, 2017               151 sec        1    -1        0
# 4        unknown   5  may, 2017                76 sec        1    -1        0
# 5        unknown   5  may, 2017                92 sec        1    -1        0
# 6        unknown   5  may, 2017               198 sec        1    -1        0
# 7        unknown   5  may, 2017               139 sec        1    -1        0
# 8        unknown   5  may, 2017               217 sec        1    -1        0
# 9        unknown   5  may, 2017               380 sec        1    -1        0
# 10       unknown   5  may, 2017                50 sec        1    -1        0
# 11       unknown   5  may, 2017                55 sec        1    -1        0
# 12       unknown   5  may, 2017               222 sec        1    -1        0
# 13       unknown   5  may, 2017               137 sec        1    -1        0
# 14       unknown   5  may, 2017               517 sec        1    -1        0
# 15       unknown   5  may, 2017                71 sec        1    -1        0
# 16       unknown   5  may, 2017               174 sec        1    -1        0
# 17       unknown   5  may, 2017               353 sec        1    -1        0
# 18       unknown   5  may, 2017                98 sec        1    -1        0
# 19       unknown   5  may, 2017                38 sec        1    -1        0
# 20       unknown   5  may, 2017               219 sec        1    -1        0
# 21       unknown   5  may, 2017                54 sec        1    -1        0
# 22       unknown   5  may, 2017               262 sec        1    -1        0
# 23       unknown   5  may, 2017               164 sec        1    -1        0
# 24       unknown   5  may, 2017               160 sec        1    -1        0
# 25       unknown   5  may, 2017               342 sec        1    -1        0
# 26       unknown   5  may, 2017               181 sec        1    -1        0
# 27       unknown   5  may, 2017               172 sec        1    -1        0
# 28       unknown   5  may, 2017               296 sec        1    -1        0
# 29       unknown   5  may, 2017               127 sec        1    -1        0
# 30       unknown   5  may, 2017               255 sec        2    -1        0
# 31       unknown   5  may, 2017               348 sec        1    -1        0
# ...          ...  ..        ...                   ...      ...   ...      ...
# 45183   cellular  15  nov, 2017  1.23333333333333 min        2   118        3
# 45184   cellular  15  nov, 2017  6.68333333333333 min        2   187        5
# 45185   cellular  15  nov, 2017               1.3 min        1    96        7
# 45186   cellular  16  nov, 2017               2.3 min        1    22        5
# 45187   cellular  16  nov, 2017  3.33333333333333 min        1    92        4
# 45188   cellular  16  nov, 2017  4.66666666666667 min        1   104        2
# 45189   cellular  16  nov, 2017              6.85 min        1    -1        0
# 45190   cellular  16  nov, 2017  3.93333333333333 min        1   550        2
# 45191   cellular  16  nov, 2017  2.88333333333333 min        1    92        5
# 45192   cellular  16  nov, 2017  3.43333333333333 min        1   188        3
# 45193   cellular  16  nov, 2017  4.36666666666667 min        1   183        1
# 45194   cellular  16  nov, 2017  3.96666666666667 min        1    -1        0
# 45195   cellular  16  nov, 2017  7.48333333333333 min        2    33        4
# 45196   cellular  16  nov, 2017               2.7 min        2   187        5
# 45197   cellular  16  nov, 2017  3.53333333333333 min        1   187        6
# 45198   cellular  16  nov, 2017               5.5 min        1    -1        0
# 45199   cellular  16  nov, 2017               4.5 min        1    -1        0
# 45200   cellular  16  nov, 2017              5.55 min        2    -1        0
# 45201   cellular  16  nov, 2017  19.4333333333333 min        3   530       12
# 45202   cellular  16  nov, 2017  25.9333333333333 min        4    -1        0
# 45203   cellular  17  nov, 2017  3.76666666666667 min        1   184        4
# 45204   cellular  17  nov, 2017  3.73333333333333 min        1    -1        0
# 45205   cellular  17  nov, 2017  4.43333333333333 min        1    -1        0
# 45206   cellular  17  nov, 2017                 5 min        1    40        8
# 45207   cellular  17  nov, 2017  6.43333333333333 min        2    -1        0
# 45208   cellular  17  nov, 2017  16.2833333333333 min        3    -1        0
# 45209   cellular  17  nov, 2017               7.6 min        2    -1        0
# 45210   cellular  17  nov, 2017  18.7833333333333 min        5   184        3
# 45211  telephone  17  nov, 2017  8.46666666666667 min        4    -1        0
# 45212   cellular  17  nov, 2017  6.01666666666667 min        2   188       11
#
# 1     poutcome response            job  education
# 2      unknown       no     management   tertiary
# 3      unknown       no     technician  secondary
# 4      unknown       no   entrepreneur  secondary
# 5      unknown       no    blue-collar    unknown
# 6      unknown       no        unknown    unknown
# 7      unknown       no     management   tertiary
# 8      unknown       no     management   tertiary
# 9      unknown       no   entrepreneur   tertiary
# 10     unknown       no        retired    primary
# 11     unknown       no     technician  secondary
# 12     unknown       no         admin.  secondary
# 13     unknown       no         admin.  secondary
# 14     unknown       no     technician  secondary
# 15     unknown       no     technician    unknown
# 16     unknown       no       services  secondary
# 17     unknown       no        retired    primary
# 18     unknown       no         admin.    unknown
# 19     unknown       no    blue-collar    primary
# 20     unknown       no        retired    primary
# 21     unknown       no       services  secondary
# 22     unknown       no    blue-collar  secondary
# 23     unknown       no     management   tertiary
# 24     unknown       no    blue-collar    primary
# 25     unknown       no       services  secondary
# 26     unknown       no        retired    primary
# 27     unknown       no         admin.  secondary
# 28     unknown       no     management   tertiary
# 29     unknown       no   entrepreneur  secondary
# 30     unknown       no     management  secondary
# 31     unknown       no     technician  secondary
# ...        ...      ...            ...        ...
# 45183  failure       no    blue-collar  secondary
# 45184  success      yes     technician  secondary
# 45185  success       no        retired    primary
# 45186  success       no        retired  secondary
# 45187  success      yes       services   tertiary
# 45188  failure       no        unknown    unknown
# 45189  unknown      yes       services  secondary
# 45190  success      yes     management  secondary
# 45191  failure       no       services  secondary
# 45192  success      yes    blue-collar  secondary
# 45193  failure      yes        retired   tertiary
# 45194  unknown      yes     management   tertiary
# 45195  success      yes  self-employed   tertiary
# 45196  failure       no     management   tertiary
# 45197  success      yes        retired  secondary
# 45198  unknown      yes        student  secondary
# 45199  unknown      yes     management  secondary
# 45200  unknown       no     management   tertiary
# 45201    other       no    blue-collar  secondary
# 45202  unknown      yes     technician  secondary
# 45203  success      yes     management   tertiary
# 45204  unknown      yes         admin.  secondary
# 45205  unknown      yes        student   tertiary
# 45206  failure      yes        retired  secondary
# 45207  unknown      yes     technician  secondary
# 45208  unknown      yes     technician   tertiary
# 45209  unknown      yes        retired    primary
# 45210  success      yes        retired  secondary
# 45211  unknown       no    blue-collar  secondary
# 45212    other       no   entrepreneur  secondary
#
# [45211 rows x 19 columns]

# %% [markdown]
# ### Segment- 4, Impute/Remove missing values

# %% [markdown]
# Take aways from the lecture on missing values:
#
# - **Set values as missing values**: Identify values that indicate missing data, for example, treat blank strings, "NA", "XX", "999", etc., as missing.
# - **Adding is good, exaggerating is bad**: You should try to get information from reliable external sources as much as possible, but if you can’t, then it is better to retain missing values rather than exaggerating the existing rows/columns.
# - **Delete rows and columns**: Rows can be deleted if the number of missing values is insignificant, as this would not impact the overall analysis results. Columns can be removed if the missing values are quite significant in number.
# - **Fill partial missing values using business judgement**: Such values include missing time zone, century, etc. These values can be identified easily.
#
# Types of missing values:
# - **MCAR**: It stands for Missing completely at random (the reason behind the missing value is not dependent on any other feature).
# - **MAR**: It stands for Missing at random (the reason behind the missing value may be associated with some other features).
# - **MNAR**: It stands for Missing not at random (there is a specific reason behind the missing value).

# %% [markdown]
# #### handling missing values in age column.

# %%
#count the missing values in age column.
inp0['age'].isna().sum()
inp0[inp0['age'].isna()]
# Out:
# 1      age  salary balance   marital                   jobedu targeted  \
# 163    NaN   60000      47    single      technician,tertiary       no
# 1023   NaN   60000    -500   married     technician,secondary      yes
# 1587   NaN  100000     123  divorced     management,secondary      yes
# 3945   NaN   70000      62   married        services,tertiary      yes
# 5677   NaN   20000     -85   married      blue-collar,primary      yes
# 6875   NaN   70000    1336  divorced       services,secondary      yes
# 9694   NaN   50000    -162    single          admin.,tertiary       no
# 11655  NaN    8000    2562    single       unemployed,primary      yes
# 13419  NaN   20000     452  divorced      blue-collar,primary      yes
# 14543  NaN   20000     -84   married    blue-collar,secondary      yes
# 17161  NaN  120000   -2082   married   entrepreneur,secondary      yes
# 19459  NaN   60000    1055   married     technician,secondary      yes
# 23485  NaN  120000     456   married   entrepreneur,secondary      yes
# 23941  NaN   20000      85   married      blue-collar,primary      yes
# 26533  NaN   60000    8112  divorced  self-employed,secondary      yes
# 35922  NaN   20000       1  divorced      blue-collar,primary      yes
# 40759  NaN   55000    3444  divorced         retired,tertiary       no
# 40996  NaN  100000    3371    single      management,tertiary       no
# 43575  NaN   16000     962   married      housemaid,secondary      yes
# 44976  NaN  100000     839   married      management,tertiary      yes
#
# 1     default housing loan   contact day      month              duration  \
# 163        no     yes   no   unknown   5  may, 2017               181 sec
# 1023       no     yes   no   unknown   7  may, 2017                78 sec
# 1587       no      no   no   unknown   8  may, 2017               306 sec
# 3945       no     yes  yes   unknown  16  may, 2017               280 sec
# 5677       no     yes  yes   unknown  26  may, 2017               118 sec
# 6875       no     yes   no   unknown  28  may, 2017               298 sec
# 9694       no     yes  yes   unknown   6  jun, 2017               119 sec
# 11655      no      no   no   unknown  20  jun, 2017               489 sec
# 13419      no     yes   no  cellular   9  jul, 2017                96 sec
# 14543      no      no  yes  cellular  15  jul, 2017              1.25 min
# 17161     yes      no  yes  cellular  28  jul, 2017              2.05 min
# 19459      no     yes   no  cellular   7  aug, 2017              4.35 min
# 23485      no     yes  yes  cellular  28  aug, 2017  2.28333333333333 min
# 23941      no      no   no  cellular  29  aug, 2017  2.21666666666667 min
# 26533      no     yes  yes  cellular  20  nov, 2017  1.06666666666667 min
# 35922      no     yes   no  cellular   8  may, 2017               0.6 min
# 40759      no      no   no  cellular  10  aug, 2017               4.2 min
# 40996      no     yes  yes  cellular  13  aug, 2017  4.73333333333333 min
# 43575      no     yes   no  cellular  28  apr, 2017  10.3833333333333 min
# 44976      no      no  yes  cellular  11  oct, 2017  6.08333333333333 min
#
# 1     campaign pdays previous poutcome response            job  education
# 163          1    -1        0  unknown       no     technician   tertiary
# 1023         5    -1        0  unknown       no     technician  secondary
# 1587         2    -1        0  unknown       no     management  secondary
# 3945         2    -1        0  unknown       no       services   tertiary
# 5677         1    -1        0  unknown       no    blue-collar    primary
# 6875         5    -1        0  unknown       no       services  secondary
# 9694         1    -1        0  unknown       no         admin.   tertiary
# 11655        2    -1        0  unknown       no     unemployed    primary
# 13419        1    -1        0  unknown       no    blue-collar    primary
# 14543        4    -1        0  unknown       no    blue-collar  secondary
# 17161        6    -1        0  unknown       no   entrepreneur  secondary
# 19459        2    -1        0  unknown       no     technician  secondary
# 23485        8    -1        0  unknown       no   entrepreneur  secondary
# 23941        4    -1        0  unknown       no    blue-collar    primary
# 26533        1    -1        0  unknown       no  self-employed  secondary
# 35922        5   336        9  failure       no    blue-collar    primary
# 40759        1   185        2  success      yes        retired   tertiary
# 40996        1    92        2  failure       no     management   tertiary
# 43575        1   181        3  success      yes      housemaid  secondary
# 44976        2   774       11  failure       no     management   tertiary

# %%
#pring the shape of dataframe inp0
inp0.shape
# Out:
# (45211, 20)

# %%
#calculate the percentage of missing values in age column.
inp0['age'].isna().sum() /len(inp0['age'])*100
# Out:
# 0.0442370219636814

# %% [markdown]
# Drop the records with age missing.

# %%
#drop the records with age missing in inp0 and copy in inp1 dataframe.
inp1= inp0.dropna(subset=['age'], how='all', inplace=True)
inp1 = inp0

# %% [markdown]
# #### handling missing values in month column

# %%
#count the missing values in month column in inp1.
#inp1['month'].isna().sum()
inp1['month'].isnull().sum()
# Out:
# 50

# %%
#print the percentage of each month in the data frame inp1.
inp1.month.unique()
# Out:
# array(['may, 2017', nan, 'jun, 2017', 'jul, 2017', 'aug, 2017',
#        'oct, 2017', 'nov, 2017', 'dec, 2017', 'jan, 2017', 'feb, 2017',
#        'mar, 2017', 'apr, 2017', 'sep, 2017'], dtype=object)

# %%
#find the mode of month in inp1
inp1.month.mode().get_values()[0]
# Out:
# 'may, 2017'

# %%
# fill the missing values with mode value of month in inp1.
l=inp1[inp1.month == inp1.month.mode().get_values()[0]]
#& inp1.month.isnull() ]

l.month.isnull().sum()
# Out:
# 0

# %%
#let's see the null values in the month column.
inp1[inp1.month.isnull()]
# Out:
# 1       age  salary balance   marital                  jobedu targeted  \
# 191    31.0  100000       0    single     management,tertiary       no
# 771    39.0   20000     245   married     blue-collar,primary      yes
# 862    33.0   55000     165   married       retired,secondary      yes
# 1269   36.0   50000     114   married        admin.,secondary      yes
# 1687   34.0   20000     457   married   blue-collar,secondary      yes
# 1901   49.0   16000     164  divorced       housemaid,primary      yes
# 2435   26.0   60000    3825   married     technician,tertiary      yes
# 2614   38.0   50000     446    single          admin.,unknown       no
# 2749   48.0  120000    2550   married    entrepreneur,unknown       no
# 3558   41.0   20000      59   married   blue-collar,secondary      yes
# 3892   56.0   55000    4391   married         retired,unknown       no
# 5313   22.0   20000       0    single   blue-collar,secondary      yes
# 6267   32.0   50000      13    single        admin.,secondary      yes
# 6398   24.0   70000       0   married       services,tertiary      yes
# 8435   38.0   60000   12926    single    technician,secondary      yes
# 8794   24.0   50000     262   married        admin.,secondary      yes
# 10629  45.0   60000     533   married     technician,tertiary      yes
# 11018  46.0   70000     741   married        services,primary      yes
# 11286  44.0   16000    1059    single       housemaid,primary      yes
# 11396  54.0   60000     415   married    technician,secondary      yes
# 14504  35.0   70000     819   married      services,secondary      yes
# 15797  38.0   20000     -41   married     blue-collar,primary      yes
# 16025  35.0   60000     328   married     technician,tertiary      yes
# 16852  45.0   55000      25   married         retired,primary      yes
# 17570  56.0   70000       0   married        services,unknown       no
# 18433  42.0   70000     247    single      services,secondary      yes
# 18944  49.0   50000     949   married        admin.,secondary      yes
# 19120  38.0   50000    1980   married         admin.,tertiary      yes
# 19771  36.0  100000     162   married     management,tertiary      yes
# 21779  56.0   16000     605   married       housemaid,primary      yes
# 21964  36.0   60000    1044    single    technician,secondary      yes
# 23899  46.0   20000     123   married     blue-collar,primary      yes
# 25660  35.0   60000    8647   married  self-employed,tertiary      yes
# 27482  31.0  100000    3283    single     management,tertiary       no
# 28695  26.0   16000     543   married      housemaid,tertiary      yes
# 30742  32.0  100000    2770    single     management,tertiary       no
# 31553  54.0   55000     136   married         retired,primary      yes
# 35775  52.0   20000      33   married     blue-collar,unknown       no
# 37196  36.0   20000    1969   married   blue-collar,secondary      yes
# 37821  34.0   20000     237   married   blue-collar,secondary      yes
# 38160  34.0   60000    1317  divorced     technician,tertiary       no
# 39190  30.0   60000     778    single    technician,secondary      yes
# 41092  35.0  100000    7218    single     management,tertiary       no
# 41436  43.0  100000   13450   married     management,tertiary      yes
# 41608  25.0  100000     808    single     management,tertiary       no
# 43003  35.0   60000     353    single  self-employed,tertiary       no
# 43023  52.0  100000    4675   married     management,tertiary      yes
# 43325  54.0   70000       0  divorced      services,secondary      yes
# 44133  27.0  100000     843    single    management,secondary      yes
# 44734  23.0    4000     508    single        student,tertiary       no
#
# 1     default housing loan    contact day month               duration  \
# 191        no     yes   no    unknown   5   NaN                562 sec
# 771        no     yes   no    unknown   7   NaN                148 sec
# 862        no      no   no    unknown   7   NaN                111 sec
# 1269       no     yes  yes    unknown   8   NaN                147 sec
# 1687       no     yes   no    unknown   9   NaN                266 sec
# 1901       no     yes   no    unknown   9   NaN               1080 sec
# 2435       no     yes   no    unknown  13   NaN                107 sec
# 2614       no     yes   no    unknown  13   NaN                386 sec
# 2749       no     yes   no    unknown  14   NaN                175 sec
# 3558       no     yes   no    unknown  15   NaN                 75 sec
# 3892       no     yes   no    unknown  16   NaN                291 sec
# 5313       no     yes   no    unknown  23   NaN                816 sec
# 6267       no     yes   no    unknown  27   NaN                 88 sec
# 6398       no     yes   no    unknown  27   NaN                299 sec
# 8435       no     yes   no    unknown   3   NaN                280 sec
# 8794       no     yes   no    unknown   4   NaN                 69 sec
# 10629      no     yes   no    unknown  16   NaN                332 sec
# 11018      no      no   no    unknown  17   NaN                161 sec
# 11286      no      no   no    unknown  18   NaN               2093 sec
# 11396      no     yes   no    unknown  19   NaN                 34 sec
# 14504      no     yes   no  telephone  14   NaN                1.7 min
# 15797      no     yes   no   cellular  21   NaN   1.13333333333333 min
# 16025      no     yes   no   cellular  22   NaN               10.9 min
# 16852      no      no  yes   cellular  25   NaN   1.91666666666667 min
# 17570      no      no   no   cellular  29   NaN   1.38333333333333 min
# 18433      no     yes   no   cellular  31   NaN                1.9 min
# 18944      no      no   no   cellular   4   NaN   1.51666666666667 min
# 19120      no      no   no   cellular   5   NaN   2.93333333333333 min
# 19771      no     yes   no   cellular   8   NaN               1.25 min
# 21779      no      no   no   cellular  19   NaN               3.45 min
# 21964      no     yes   no   cellular  20   NaN               0.25 min
# 23899      no      no   no   cellular  29   NaN                2.8 min
# 25660      no      no   no   cellular  19   NaN   2.33333333333333 min
# 27482      no      no   no   cellular  21   NaN   6.28333333333333 min
# 28695      no      no   no   cellular  30   NaN   2.81666666666667 min
# 30742      no      no   no  telephone   6   NaN  0.733333333333333 min
# 31553      no     yes   no   cellular   3   NaN   5.86666666666667 min
# 35775      no      no   no  telephone   8   NaN   5.01666666666667 min
# 37196      no     yes  yes   cellular  13   NaN               1.45 min
# 37821      no     yes   no   cellular  14   NaN   1.91666666666667 min
# 38160      no     yes   no   cellular  15   NaN   3.98333333333333 min
# 39190      no     yes   no   cellular  18   NaN  0.366666666666667 min
# 41092      no      no   no   cellular  14   NaN   3.73333333333333 min
# 41436      no     yes   no   cellular   4   NaN   2.13333333333333 min
# 41608      no      no   no   cellular  18   NaN               4.45 min
# 43003      no      no   no   cellular  11   NaN   5.86666666666667 min
# 43023      no      no   no   cellular  12   NaN   3.01666666666667 min
# 43325      no      no   no   cellular  18   NaN   6.03333333333333 min
# 44133      no      no   no   cellular  12   NaN               2.05 min
# 44734      no      no   no   cellular   8   NaN                3.5 min
#
# 1     campaign pdays previous poutcome response            job  education
# 191          1    -1        0  unknown       no     management   tertiary
# 771          3    -1        0  unknown       no    blue-collar    primary
# 862          1    -1        0  unknown       no        retired  secondary
# 1269         1    -1        0  unknown       no         admin.  secondary
# 1687         1    -1        0  unknown       no    blue-collar  secondary
# 1901         5    -1        0  unknown       no      housemaid    primary
# 2435         1    -1        0  unknown       no     technician   tertiary
# 2614         1    -1        0  unknown       no         admin.    unknown
# 2749         3    -1        0  unknown       no   entrepreneur    unknown
# 3558         8    -1        0  unknown       no    blue-collar  secondary
# 3892         1    -1        0  unknown       no        retired    unknown
# 5313         2    -1        0  unknown       no    blue-collar  secondary
# 6267         2    -1        0  unknown       no         admin.  secondary
# 6398         1    -1        0  unknown       no       services   tertiary
# 8435         1    -1        0  unknown       no     technician  secondary
# 8794         3    -1        0  unknown       no         admin.  secondary
# 10629        2    -1        0  unknown       no     technician   tertiary
# 11018        3    -1        0  unknown       no       services    primary
# 11286        1    -1        0  unknown      yes      housemaid    primary
# 11396       31    -1        0  unknown       no     technician  secondary
# 14504       14    -1        0  unknown       no       services  secondary
# 15797       10    -1        0  unknown       no    blue-collar    primary
# 16025        2    -1        0  unknown      yes     technician   tertiary
# 16852        3    -1        0  unknown       no        retired    primary
# 17570        2    -1        0  unknown       no       services    unknown
# 18433        2    -1        0  unknown       no       services  secondary
# 18944        1    -1        0  unknown       no         admin.  secondary
# 19120        2    -1        0  unknown       no         admin.   tertiary
# 19771        2    -1        0  unknown       no     management   tertiary
# 21779        6    -1        0  unknown       no      housemaid    primary
# 21964       19    -1        0  unknown       no     technician  secondary
# 23899        2    -1        0  unknown       no    blue-collar    primary
# 25660        2    -1        0  unknown       no  self-employed   tertiary
# 27482        1    -1        0  unknown       no     management   tertiary
# 28695        3    -1        0  unknown       no      housemaid   tertiary
# 30742        9    -1        0  unknown       no     management   tertiary
# 31553        1   332        2  failure       no        retired    primary
# 35775        1    -1        0  unknown       no    blue-collar    unknown
# 37196        1    -1        0  unknown       no    blue-collar  secondary
# 37821        3    -1        0  unknown       no    blue-collar  secondary
# 38160        1    -1        0  unknown       no     technician   tertiary
# 39190        2   346        2  failure       no     technician  secondary
# 41092        3    -1        0  unknown       no     management   tertiary
# 41436        1    -1        0  unknown       no     management   tertiary
# 41608        2   114        2  failure      yes     management   tertiary
# 43003        1   183        1  success      yes  self-employed   tertiary
# 43023        3    -1        0  unknown      yes     management   tertiary
# 43325        1   290        3  success      yes       services  secondary
# 44133        2   185        1  success       no     management  secondary
# 44734        1    92        1  failure       no        student   tertiary

# %% [markdown]
# #### handling missing values in response column

# %%
#count the missing values in response column in inp1.
inp1.response.isnull().sum()
# Out:
# 30

# %%
#calculate the percentage of missing values in response column. 
inp1.response.isnull().sum()/len(inp1.response)*100
# Out:
# 0.06638489964816004

# %% [markdown]
# Target variable is better of not imputed.
# - Drop the records with missing values.

# %%
#drop the records with response missings in inp1.
inp1.dropna(subset=['response'],how='all',inplace=True)

# %%
#calculate the missing values in each column of data frame: inp1.
inp1.isnull().sum()
# Out:
# 1
# age           0
# salary        0
# balance       0
# marital       0
# jobedu        0
# targeted      0
# default       0
# housing       0
# loan          0
# contact       0
# day           0
# month        50
# duration      0
# campaign      0
# pdays         0
# previous      0
# poutcome      0
# response      0
# job           0
# education     0
# dtype: int64

# %% [markdown]
# #### handling pdays column.

# %%
#describe the pdays column of inp1.
inp1.pdays.describe()
# Out:
# count     45161
# unique      835
# top          -1
# freq      30244
# Name: pdays, dtype: object

# %% [markdown]
# -1 indicates the missing values.
# Missing value does not always be present as null.
# How to handle it:
#
# Objective is:
# - you should ignore the missing values in the calculations
# - simply make it missing - replace -1 with NaN.
# - all summary statistics- mean, median etc. we will ignore the missing values of pdays.

# %%
#describe the pdays column with considering the -1 values.
inp1[inp1['pdays']==-1]
# Out:
# 1       age  salary balance   marital                  jobedu targeted  \
# 32768  51.0   20000     528   married   blue-collar,secondary      yes
# 32769  35.0  100000    3217   married     management,tertiary      yes
# 32771  39.0   20000     390   married     blue-collar,primary      yes
# 32773  39.0  100000     315   married    management,secondary      yes
# 32774  32.0  100000     703    single     management,tertiary       no
# 32775  38.0   50000     424   married        admin.,secondary      yes
# 32776  36.0  100000     -26   married     management,tertiary      yes
# 32778  39.0   50000     248   married        admin.,secondary      yes
# 32779  35.0   20000    2200   married   blue-collar,secondary      yes
# 32780  38.0   50000     382  divorced        admin.,secondary      yes
# 32781  34.0   70000     277   married       services,tertiary      yes
# 32782  39.0   70000     186   married      services,secondary      yes
# 32784  33.0   60000    9305   married    technician,secondary      yes
# 32785  34.0   20000     678   married   blue-collar,secondary      yes
# 32786  35.0   20000     270    single   blue-collar,secondary      yes
# 32787  35.0   50000     437   married        admin.,secondary      yes
# 32790  32.0   60000    -109    single     technician,tertiary       no
# 32792  37.0   20000     395   married   blue-collar,secondary      yes
# 32793  61.0   55000     876  divorced         retired,primary      yes
# 32794  37.0  120000     209   married  entrepreneur,secondary      yes
# 32796  32.0   60000     801    single    technician,secondary      yes
# 32797  52.0   20000     940   married     blue-collar,primary      yes
# 32798  44.0   50000     266   married        admin.,secondary      yes
# 32799  37.0   20000    3977   married     blue-collar,primary      yes
# 32804  71.0   55000    2988   married         retired,primary      yes
# 32805  36.0   70000      92    single      services,secondary      yes
# 32807  40.0   50000     824   married        admin.,secondary      yes
# 32809  34.0  120000    2945    single   entrepreneur,tertiary       no
# 32810  55.0  100000     566   married    management,secondary      yes
# 32811  31.0   70000     371   married      services,secondary      yes
# ...     ...     ...     ...       ...                     ...      ...
# 45094  43.0  100000    2081    single     management,tertiary       no
# 45102  34.0   20000     152   married   blue-collar,secondary      yes
# 45110  36.0   60000     844   married     technician,tertiary      yes
# 45117  30.0  100000     565    single     management,tertiary       no
# 45124  40.0  120000     262    single   entrepreneur,tertiary       no
# 45126  27.0   20000     232    single     blue-collar,primary      yes
# 45127  40.0  100000     858  divorced     management,tertiary       no
# 45129  67.0   20000   16353   married   blue-collar,secondary      yes
# 45133  47.0  100000       0   married     management,tertiary      yes
# 45137  53.0   20000    1294   married     blue-collar,primary      yes
# 45139  30.0  100000     297    single     management,tertiary       no
# 45146  60.0   50000     683  divorced        admin.,secondary      yes
# 45147  28.0   70000     441    single       services,tertiary       no
# 45158  37.0  100000    3556   married     management,tertiary      yes
# 45163  31.0  100000     720   married     management,tertiary      yes
# 45166  35.0   70000    4655   married       services,tertiary      yes
# 45169  48.0   50000     178   married        admin.,secondary      yes
# 45178  54.0   50000      66   married        admin.,secondary      yes
# 45189  32.0   70000    1168    single      services,secondary      yes
# 45194  29.0  100000     765    single     management,tertiary       no
# 45198  25.0    4000     358    single       student,secondary      yes
# 45199  36.0  100000    1511    single    management,secondary      yes
# 45200  37.0  100000    1428   married     management,tertiary      yes
# 45202  38.0   60000     557   married    technician,secondary      yes
# 45204  34.0   50000     557    single        admin.,secondary      yes
# 45205  23.0    4000     113    single        student,tertiary       no
# 45207  25.0   60000     505    single    technician,secondary      yes
# 45208  51.0   60000     825   married     technician,tertiary      yes
# 45209  71.0   55000    1729  divorced         retired,primary      yes
# 45211  57.0   20000     668   married   blue-collar,secondary      yes
#
# 1     default housing loan    contact day      month               duration  \
# 32768      no     yes   no   cellular  17  apr, 2017                5.4 min
# 32769      no     yes  yes   cellular  17  apr, 2017   3.58333333333333 min
# 32771      no     yes   no   cellular  17  apr, 2017   3.43333333333333 min
# 32773      no     yes   no  telephone  17  apr, 2017               2.35 min
# 32774      no     yes   no   cellular  17  apr, 2017   3.33333333333333 min
# 32775      no     yes   no   cellular  17  apr, 2017               4.65 min
# 32776      no      no   no   cellular  17  apr, 2017   3.56666666666667 min
# 32778      no     yes   no   cellular  17  apr, 2017   10.8166666666667 min
# 32779      no     yes   no   cellular  17  apr, 2017  0.233333333333333 min
# 32780      no     yes   no   cellular  17  apr, 2017   6.61666666666667 min
# 32781      no     yes   no   cellular  17  apr, 2017                1.2 min
# 32782      no     yes   no   cellular  17  apr, 2017   7.21666666666667 min
# 32784      no     yes   no   cellular  17  apr, 2017   6.78333333333333 min
# 32785      no     yes   no   cellular  17  apr, 2017   4.63333333333333 min
# 32786      no     yes   no   cellular  17  apr, 2017                3.6 min
# 32787      no     yes   no   cellular  17  apr, 2017               2.05 min
# 32790      no     yes  yes   cellular  17  apr, 2017   6.98333333333333 min
# 32792      no     yes   no   cellular  17  apr, 2017   2.61666666666667 min
# 32793      no      no   no   cellular  17  apr, 2017  0.666666666666667 min
# 32794      no     yes   no   cellular  17  apr, 2017   1.66666666666667 min
# 32796      no     yes   no   cellular  17  apr, 2017   10.6166666666667 min
# 32797      no     yes   no   cellular  17  apr, 2017   5.28333333333333 min
# 32798      no     yes   no   cellular  17  apr, 2017                4.9 min
# 32799      no     yes   no   cellular  17  apr, 2017                4.4 min
# 32804      no      no   no  telephone  17  apr, 2017   2.16666666666667 min
# 32805      no     yes   no   cellular  17  apr, 2017                0.6 min
# 32807      no     yes   no   cellular  17  apr, 2017   5.98333333333333 min
# 32809      no     yes   no   cellular  17  apr, 2017   4.43333333333333 min
# 32810      no     yes   no   cellular  17  apr, 2017   1.78333333333333 min
# 32811      no     yes  yes   cellular  17  apr, 2017               10.9 min
# ...       ...     ...  ...        ...  ..        ...                    ...
# 45094      no      no   no   cellular  22  oct, 2017   9.23333333333333 min
# 45102      no      no   no   cellular  25  oct, 2017   4.58333333333333 min
# 45110      no     yes  yes   cellular  25  oct, 2017               2.15 min
# 45117      no     yes   no   cellular  26  oct, 2017   1.73333333333333 min
# 45124      no     yes  yes    unknown  26  oct, 2017  0.283333333333333 min
# 45126      no     yes   no   cellular  26  oct, 2017   11.6833333333333 min
# 45127      no      no   no   cellular  26  oct, 2017   3.36666666666667 min
# 45129      no      no   no   cellular  27  oct, 2017   3.71666666666667 min
# 45133      no      no   no   cellular  27  oct, 2017   8.46666666666667 min
# 45137      no      no   no    unknown  28  oct, 2017   1.18333333333333 min
# 45139      no      no   no   cellular   8  nov, 2017   3.13333333333333 min
# 45146      no      no   no   cellular   8  nov, 2017               8.45 min
# 45147      no      no   no   cellular   8  nov, 2017   1.76666666666667 min
# 45158      no      no   no   cellular   9  nov, 2017   4.46666666666667 min
# 45163      no     yes   no   cellular   9  nov, 2017   1.56666666666667 min
# 45166      no      no   no   cellular   9  nov, 2017               1.85 min
# 45169      no      no   no   cellular  10  nov, 2017                3.8 min
# 45178      no     yes   no   cellular  11  nov, 2017   2.78333333333333 min
# 45189      no     yes   no   cellular  16  nov, 2017               6.85 min
# 45194      no      no   no   cellular  16  nov, 2017   3.96666666666667 min
# 45198      no      no   no   cellular  16  nov, 2017                5.5 min
# 45199      no     yes   no   cellular  16  nov, 2017                4.5 min
# 45200      no      no   no   cellular  16  nov, 2017               5.55 min
# 45202      no     yes   no   cellular  16  nov, 2017   25.9333333333333 min
# 45204      no      no   no   cellular  17  nov, 2017   3.73333333333333 min
# 45205      no      no   no   cellular  17  nov, 2017   4.43333333333333 min
# 45207      no      no  yes   cellular  17  nov, 2017   6.43333333333333 min
# 45208      no      no   no   cellular  17  nov, 2017   16.2833333333333 min
# 45209      no      no   no   cellular  17  nov, 2017                7.6 min
# 45211      no      no   no  telephone  17  nov, 2017   8.46666666666667 min
#
# 1     campaign pdays previous poutcome response           job  education
# 32768        3    -1        0  unknown       no   blue-collar  secondary
# 32769        1    -1        0  unknown       no    management   tertiary
# 32771        1    -1        0  unknown       no   blue-collar    primary
# 32773        4    -1        0  unknown       no    management  secondary
# 32774        3    -1        0  unknown       no    management   tertiary
# 32775        1    -1        0  unknown       no        admin.  secondary
# 32776        2    -1        0  unknown       no    management   tertiary
# 32778        1    -1        0  unknown       no        admin.  secondary
# 32779        1    -1        0  unknown       no   blue-collar  secondary
# 32780        1    -1        0  unknown       no        admin.  secondary
# 32781        4    -1        0  unknown       no      services   tertiary
# 32782        1    -1        0  unknown       no      services  secondary
# 32784        2    -1        0  unknown       no    technician  secondary
# 32785        1    -1        0  unknown       no   blue-collar  secondary
# 32786        1    -1        0  unknown       no   blue-collar  secondary
# 32787        1    -1        0  unknown       no        admin.  secondary
# 32790        1    -1        0  unknown       no    technician   tertiary
# 32792        2    -1        0  unknown       no   blue-collar  secondary
# 32793        9    -1        0  unknown       no       retired    primary
# 32794        1    -1        0  unknown       no  entrepreneur  secondary
# 32796        1    -1        0  unknown       no    technician  secondary
# 32797        1    -1        0  unknown       no   blue-collar    primary
# 32798        2    -1        0  unknown       no        admin.  secondary
# 32799        1    -1        0  unknown       no   blue-collar    primary
# 32804        1    -1        0  unknown      yes       retired    primary
# 32805        1    -1        0  unknown       no      services  secondary
# 32807        1    -1        0  unknown       no        admin.  secondary
# 32809        1    -1        0  unknown       no  entrepreneur   tertiary
# 32810        1    -1        0  unknown       no    management  secondary
# 32811        1    -1        0  unknown       no      services  secondary
# ...        ...   ...      ...      ...      ...           ...        ...
# 45094        3    -1        0  unknown      yes    management   tertiary
# 45102        1    -1        0  unknown       no   blue-collar  secondary
# 45110        1    -1        0  unknown       no    technician   tertiary
# 45117        1    -1        0  unknown       no    management   tertiary
# 45124        1    -1        0  unknown       no  entrepreneur   tertiary
# 45126        2    -1        0  unknown      yes   blue-collar    primary
# 45127        2    -1        0  unknown      yes    management   tertiary
# 45129        2    -1        0  unknown       no   blue-collar  secondary
# 45133        1    -1        0  unknown      yes    management   tertiary
# 45137        1    -1        0  unknown       no   blue-collar    primary
# 45139        1    -1        0  unknown      yes    management   tertiary
# 45146        1    -1        0  unknown       no        admin.  secondary
# 45147        1    -1        0  unknown       no      services   tertiary
# 45158        1    -1        0  unknown      yes    management   tertiary
# 45163        3    -1        0  unknown       no    management   tertiary
# 45166        2    -1        0  unknown       no      services   tertiary
# 45169        1    -1        0  unknown       no        admin.  secondary
# 45178        1    -1        0  unknown      yes        admin.  secondary
# 45189        1    -1        0  unknown      yes      services  secondary
# 45194        1    -1        0  unknown      yes    management   tertiary
# 45198        1    -1        0  unknown      yes       student  secondary
# 45199        1    -1        0  unknown      yes    management  secondary
# 45200        2    -1        0  unknown       no    management   tertiary
# 45202        4    -1        0  unknown      yes    technician  secondary
# 45204        1    -1        0  unknown      yes        admin.  secondary
# 45205        1    -1        0  unknown      yes       student   tertiary
# 45207        2    -1        0  unknown      yes    technician  secondary
# 45208        3    -1        0  unknown      yes    technician   tertiary
# 45209        2    -1        0  unknown      yes       retired    primary
# 45211        4    -1        0  unknown       no   blue-collar  secondary
#
# [6671 rows x 20 columns]

# %% [markdown]
# ### Segment- 5, Handling Outliers

# %% [markdown]
# Major approaches to the treat outliers:
#
# - **Imputation**
# - **Deletion of outliers**
# - **Binning of values**
# - **Cap the outlier**

# %% [markdown]
# #### Age variable

# %%
#describe the age variable in inp1.
inp1.age.describe()
# Out:
# count    45161.000000
# mean        40.935763
# std         10.618790
# min         18.000000
# 25%         33.000000
# 50%         39.000000
# 75%         48.000000
# max         95.000000
# Name: age, dtype: float64

# %%
#plot the histogram of age variable.
inp1.age.plot.hist()

# %%
#plot the boxplot of age variable.
inp1.age.plot.box()

# %% [markdown]
# #### Salary variable

# %%
#describe the salary variable of inp1.
inp1.salary.describe()
# Out:
# count     45161
# unique       22
# top       20000
# freq       7282
# Name: salary, dtype: object

# %%
#plot the boxplot of salary variable.
inp1.salary.astype(float).plot.box()

# %% [markdown]
# #### Balance variable

# %%
#describe the balance variable of inp1.
inp1.balance.describe()
# Out:
# count     45161
# unique    10329
# top           0
# freq       2764
# Name: balance, dtype: object

# %%
#plot the boxplot of balance variable.
inp1.balance.astype(float).plot.box()

# %%
#plot the boxplot of balance variable after scaling in 8:2.
plt.figure(figsize=[8,2])
sns.boxplot(inp1.balance)
plt.show()

# %%
#print the quantile (0.5, 0.7, 0.9, 0.95 and 0.99) of balance variable
inp1['balance'].quantile([0.5, 0.7, 0.9, 0.95 , 0.99], interpolation='nearest')
# Out:
# 0.50      448.0
# 0.70     1126.0
# 0.90     3576.0
# 0.95     5769.0
# 0.99    13165.0
# Name: balance, dtype: float64

# %% [markdown]
# ### Segment- 6, Standardising values

# %% [markdown]
# Checklist for data standardization exercises:
# - **Standardise units**: Ensure all observations under one variable are expressed in a common and consistent unit, e.g., convert lbs to kg, miles/hr to km/hr, etc.
# - **Scale values if required**: Make sure all the observations under one variable have a common scale.
# - **Standardise precision** for better presentation of data, e.g., change 4.5312341 kg to 4.53 kg.
# - **Remove extra characters** such as common prefixes/suffixes, leading/trailing/multiple spaces, etc. These are irrelevant to analysis.
# - **Standardise case**: String variables may take various casing styles, e.g., UPPERCASE, lowercase, Title Case, Sentence case, etc.
# - **Standardise format**: It is important to standardise the format of other elements such as date, name, etce.g., change 23/10/16 to 2016/10/23, “Modi, Narendra” to “Narendra Modi", etc.

# %% [markdown]
# #### Duration variable

# %%
#describe the duration variable of inp1
inp1.duration.describe()
# Out:
# count       45161
# unique       2646
# top       1.5 min
# freq          138
# Name: duration, dtype: object

# %%
#convert the duration variable into single unit i.e. minutes. and remove the sec or min prefix.
inp1['duration'] = np.where(inp1.duration.str.contains('sec'),inp1.duration.str.split().str[0].astype(float)/60,inp1.duration.str.split().str[0])

# %%
#describe the duration variable
inp1.duration.describe()
# Out:
# count     45161
# unique     2646
# top         1.5
# freq        138
# Name: duration, dtype: object

# %% [markdown]
# ## Session- 3, Univariate Analysis

# %% [markdown]
# ### Segment- 2, Categorical unordered univariate analysis

# %% [markdown]
# Unordered data do not have the notion of high-low, more-less etc. Example:
# - Type of loan taken by a person = home, personal, auto etc.
# - Organisation of a person = Sales, marketing, HR etc.
# - Job category of persone.
# - Marital status of any one.

# %% [markdown]
# #### Marital status

# %%
#calculate the percentage of each marital status category. 
inp1.marital.value_counts(normalize=True)*100
# Out:
# married     60.195744
# single      28.294325
# divorced    11.509931
# Name: marital, dtype: float64

# %%
#plot the bar graph of percentage marital status categories
inp1.marital.value_counts(normalize=True).plot.bar()

# %% [markdown]
# #### Job

# %%
#calculate the percentage of each job status category.
inp1.job.value_counts(normalize=True)*100
# Out:
# blue-collar      21.527424
# management       20.927349
# technician       16.804322
# admin.           11.436859
# services          9.184916
# retired           5.008746
# self-employed     3.485308
# entrepreneur      3.286021
# unemployed        2.883019
# housemaid         2.741303
# student           2.077013
# unknown           0.637718
# Name: job, dtype: float64

# %%
#plot the bar graph of percentage job categories
(inp1.job.value_counts(normalize=True)*100).plot.bar()

# %% [markdown]
# ### Segment- 3, Categorical ordered univariate analysis

# %% [markdown]
# Ordered variables have some kind of ordering. Some examples of bank marketing dataset are:
# - Age group= <30, 30-40, 40-50 and so on.
# - Month = Jan-Feb-Mar etc.
# - Education = primary, secondary and so on.

# %% [markdown]
# #### Education

# %%
#calculate the percentage of each education category.
inp1.education.value_counts(normalize=True)
# Out:
# secondary    0.513275
# tertiary     0.294192
# primary      0.151436
# unknown      0.041097
# Name: education, dtype: float64

# %%
#plot the pie chart of education categories
inp1.education.value_counts(normalize=True).plot.pie()

# %% [markdown]
# #### poutcome

# %%
#calculate the percentage of each poutcome category.
inp1.poutcome.value_counts(normalize=True)
# Out:
# unknown    0.817520
# failure    0.108368
# other      0.040721
# success    0.033392
# Name: poutcome, dtype: float64

# %% [markdown]
# #### Response the target variable

# %%
#calculate the percentage of each response category.
inp1.response.value_counts(normalize=True)
# Out:
# no     0.882974
# yes    0.117026
# Name: response, dtype: float64

# %%
#plot the pie chart of response categories
inp1.response.value_counts(normalize=True).plot.pie()

# %% [markdown]
# ## Session- 4, Bivariate and Multivariate Analysis

# %% [markdown]
# ### Segment-2, Numeric- numeric analysis

# %% [markdown]
# There are three ways to analyse the numeric- numeric data types simultaneously.
# - **Scatter plot**: describes the pattern that how one variable is varying with other variable.
# - **Correlation matrix**: to describe the linearity of two numeric variables.
# - **Pair plot**: group of scatter plots of all numeric variables in the data frame.

# %%
#plot the scatter plot of balance and salary variable in inp1
inp1['salary'] =inp1.salary.astype('float')
inp1['balance'] =inp1.balance.astype('float')
inp1.plot.scatter(x='salary',y='balance')

# %%
#plot the scatter plot of balance and age variable in inp1
inp1['age'] =inp1.age.astype('float')
inp1['balance'] =inp1.balance.astype('float')
inp1.plot.scatter(x='balance',y='age')

# %%
#plot the pair plot of salary, balance and age in inp1 dataframe.
sns.pairplot(data=inp1,vars=['salary', 'balance', 'age'])
plt.show()

# %% [markdown]
# #### Correlation heat map

# %%
#plot the correlation matrix of salary, balance and age in inp1 dataframe.
inp1[['salary','balance','age']].corr()
# Out:
# 1          salary   balance       age
# 1
# salary   1.000000  0.055489  0.024513
# balance  0.055489  1.000000  0.097710
# age      0.024513  0.097710  1.000000

# %%
sns.heatmap(inp1[['salary','balance','age']].corr(), annot=True)

# %% [markdown]
# ### Segment- 4, Numerical categorical variable

# %% [markdown]
# #### Salary vs response

# %%
#groupby the response to find the mean of the salary with response no & yes seperatly.
inp1.groupby('response')['salary'].mean()
# Out:
# response
# no     56769.510482
# yes    58780.510880
# Name: salary, dtype: float64

# %%
#groupby the response to find the median of the salary with response no & yes seperatly.
inp1.groupby('response')['salary'].median()
# Out:
# response
# no     60000.0
# yes    60000.0
# Name: salary, dtype: float64

# %%
#plot the box plot of salary for yes & no responses.
sns.boxplot(data=inp1,x='response',y='salary')

# %% [markdown]
# #### Balance vs response

# %%
#plot the box plot of balance for yes & no responses.
sns.boxplot(data=inp1, x='response', y='balance')

# %%
#groupby the response to find the mean of the balance with response no & yes seperatly.
inp1.groupby('response')['balance'].mean()
# Out:
# response
# no     1304.292281
# yes    1804.681362
# Name: balance, dtype: float64

# %%
#groupby the response to find the median of the balance with response no & yes seperatly.
inp1.groupby('response')['balance'].median()
# Out:
# response
# no     417.0
# yes    733.0
# Name: balance, dtype: float64

# %% [markdown]
# ##### 75th percentile

# %%
#function to find the 75th percentile.
def p75(x):
    return np.quantile(x, 0.75)

# %%
#calculate the mean, median and 75th percentile of balance with response
inp1.groupby('response')['balance'].aggregate(['mean','median',p75])
# Out:
#                  mean  median     p75
# response
# no        1304.292281   417.0  1345.0
# yes       1804.681362   733.0  2159.0

# %%
#plot the bar graph of balance's mean an median with response.
inp1.groupby('response')['balance'].aggregate(['mean','median']).plot.bar()

# %% [markdown]
# #### Education vs salary

# %%
#groupby the education to find the mean of the salary education category.
inp1.groupby(['education'])['salary'].mean()
# Out:
# education
# primary      34232.343910
# secondary    49731.449525
# tertiary     82880.249887
# unknown      46529.633621
# Name: salary, dtype: float64

# %%
#groupby the education to find the median of the salary for each education category.
inp1.groupby(['education'])['salary'].median()
# Out:
# education
# primary       20000.0
# secondary     55000.0
# tertiary     100000.0
# unknown       50000.0
# Name: salary, dtype: float64

# %% [markdown]
# #### Job vs salary

# %%
#groupby the job to find the mean of the salary for each job category.
inp1.groupby(['job'])['salary'].mean()
# Out:
# job
# admin.            50000.0
# blue-collar       20000.0
# entrepreneur     120000.0
# housemaid         16000.0
# management       100000.0
# retired           55000.0
# self-employed     60000.0
# services          70000.0
# student            4000.0
# technician        60000.0
# unemployed         8000.0
# unknown               0.0
# Name: salary, dtype: float64

# %% [markdown]
# ### Segment- 5, Categorical categorical variable

# %%
#create response_flag of numerical data type where response "yes"= 1, "no"= 0
inp1['response_flag']=np.where(inp1.response=='yes',1,0)

# %% [markdown]
# #### Education vs response rate

# %%
#calculate the mean of response_flag with different education categories.
inp1.groupby(['education'])['response_flag'].mean()
# Out:
# education
# primary      0.086416
# secondary    0.105608
# tertiary     0.150083
# unknown      0.135776
# Name: response_flag, dtype: float64

# %% [markdown]
# #### Marital vs response rate

# %%
#calculate the mean of response_flag with different marital status categories.
inp1.groupby(['marital'])['response_flag'].mean()
# Out:
# marital
# divorced    0.119469
# married     0.101269
# single      0.149554
# Name: response_flag, dtype: float64

# %%
#plot the bar graph of marital status with average value of response_flag
inp1.groupby(['marital'])['response_flag'].mean().plot.barh()

# %% [markdown]
# #### Loans vs response rate

# %%
#plot the bar graph of personal loan status with average value of response_flag
inp1.groupby(['loan'])['response_flag'].mean().plot.barh()

# %% [markdown]
# #### Housing loans vs response rate

# %%
#plot the bar graph of housing loan status with average value of response_flag
inp1.groupby(['housing'])['response_flag'].mean().plot.barh()

# %% [markdown]
# #### Age vs response

# %%
#plot the boxplot of age with response_flag
sns.boxplot(data=inp1, x='response_flag',y='age')

# %% [markdown]
# ##### making buckets from age columns

# %%
pd.cut?

# %%
#create the buckets of <30, 30-40, 40-50 50-60 and 60+ from age column.
pd.cut(inp1.age,[0,30,40,50,60,9999],labels=['<30', '30-40', '40-50', '50-60', '60+'])
# Out:
# 2        50-60
# 3        40-50
# 4        30-40
# 5        40-50
# 6        30-40
# 7        30-40
# 8          <30
# 9        40-50
# 10       50-60
# 11       40-50
# 12       40-50
# 13         <30
# 14       50-60
# 15       50-60
# 16       50-60
# 17       50-60
# 18       40-50
# 19       50-60
# 20       50-60
# 21       30-40
# 22         <30
# 23       50-60
# 24       30-40
# 25         <30
# 26       30-40
# 27       40-50
# 28       30-40
# 29       50-60
# 30       40-50
# 31       30-40
#          ...
# 45183    40-50
# 45184    30-40
# 45185      60+
# 45186      60+
# 45187    50-60
# 45188    50-60
# 45189    30-40
# 45190      <30
# 45191      <30
# 45192    30-40
# 45193      60+
# 45194      <30
# 45195      <30
# 45196    50-60
# 45197      60+
# 45198      <30
# 45199    30-40
# 45200    30-40
# 45201    30-40
# 45202    30-40
# 45203    50-60
# 45204    30-40
# 45205      <30
# 45206      60+
# 45207      <30
# 45208    50-60
# 45209      60+
# 45210      60+
# 45211    50-60
# 45212    30-40
# Name: age, Length: 45161, dtype: category
# Categories (5, object): [<30 < 30-40 < 40-50 < 50-60 < 60+]

# %%
inp1['age_group']=pd.cut(inp1.age,[0,30,40,50,60,9999],labels=['<30', '30-40', '40-50', '50-60', '60+'])

# %%
#plot the percentage of each buckets and average values of response_flag in each buckets. plot in subplots.
inp1.age_group.value_counts(normalize=True)*100
# Out:
# 30-40    39.108966
# 40-50    24.868803
# 50-60    17.840615
# <30      15.555457
# 60+       2.626160
# Name: age_group, dtype: float64

# %%
plt.figure(figsize=[16,9])
plt.subplot(1,2,1)
inp1.age_group.value_counts(normalize=True).plot.bar()
plt.subplot(1,2,2)
inp1.groupby(['age_group'])['response_flag'].mean().plot.bar()

# %%
#plot the bar graph of job categories with response_flag mean value.
inp1.groupby(['job'])['response_flag'].mean().plot.barh()

# %% [markdown]
# ### Segment-6, Multivariate analysis

# %%
res =pd.pivot_table(data=inp1,index='education',columns='marital',values='response_flag')
res
# Out:
# marital    divorced   married    single
# education
# primary    0.138852  0.075601  0.106808
# secondary  0.103559  0.094650  0.129271
# tertiary   0.137415  0.129835  0.183737
# unknown    0.142012  0.122519  0.162879

# %% [markdown]
# #### Education vs marital vs response

# %%
#create heat map of education vs marital vs response_flag
sns.heatmap(res,annot=True, cmap='RdYlGn',center=0.117)

# %% [markdown]
# #### Job vs marital vs response

# %%
#create the heat map of Job vs marital vs response_flag.
res1 = pd.pivot_table(data=inp1,index='marital',columns='job',values='response_flag')
res1
# Out:
# job         admin.  blue-collar  entrepreneur  housemaid  management  \
# marital
# divorced  0.120160     0.077644      0.083799   0.097826    0.127928
# married   0.113383     0.062778      0.075843   0.072527    0.126228
# single    0.136153     0.105760      0.113924   0.166667    0.162254
#
# job        retired  self-employed  services   student  technician  unemployed  \
# marital
# divorced  0.283688       0.158273  0.091241  0.166667    0.083243    0.157895
# married   0.220682       0.079637  0.074105  0.185185    0.102767    0.132695
# single    0.120370       0.191874  0.117696  0.293850    0.132645    0.195000
#
# job        unknown
# marital
# divorced  0.058824
# married   0.103448
# single    0.176471

# %%
sns.heatmap(res,annot=True, cmap='RdYlGn')

# %% [markdown]
# #### Education vs poutcome vs response

# %%
#create the heat map of education vs poutcome vs response_flag.
res2 = pd.pivot_table(data=inp1,index='education',columns='poutcome',values='response_flag')
res2
# Out:
# poutcome    failure     other   success   unknown
# education
# primary    0.088785  0.143443  0.609023  0.071821
# secondary  0.109007  0.140831  0.641902  0.084244
# tertiary   0.168683  0.220994  0.657005  0.114256
# unknown    0.158192  0.200000  0.679012  0.101761

# %%
sns.heatmap(res2,annot=True, cmap='RdYlGn')
